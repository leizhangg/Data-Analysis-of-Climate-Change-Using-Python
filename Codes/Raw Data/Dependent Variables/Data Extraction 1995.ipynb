# %%
import pandas as pd

# %%
raw_data = pd.read_csv(r'C:\Users\Shilp\Documents\Shilpa\Shilpa MSBA\Semester 1\Programming for Analytics [CIS 9650]\Final Group Project\Raw data\Extracted data\1995.csv (extract.me)\s104WRWsRP9e', header=1)

# %%
raw_data.columns = ['station', 'date','metric_name','metric_value','var1','var2','var3','var4']

# %%
raw_data.head()
# Out:
#        station      date metric_name  metric_value var1 var2 var3  var4
# 0  AE000041196  19950101        TAVG           189    H  NaN    S   NaN
# 1  AEM00041194  19950101        TMAX           238  NaN  NaN    S   NaN
# 2  AEM00041194  19950101        TMIN           120  NaN  NaN    S   NaN
# 3  AEM00041194  19950101        TAVG           198    H  NaN    S   NaN
# 4  AEM00041218  19950101        TMAX           238  NaN  NaN    S   NaN

# %%
raw_data['country'] = raw_data['station'].astype(str).str[:2]

# %%
raw_data.head()
# Out:
#        station      date metric_name  metric_value var1 var2 var3  var4  \
# 0  AE000041196  19950101        TAVG           189    H  NaN    S   NaN
# 1  AEM00041194  19950101        TMAX           238  NaN  NaN    S   NaN
# 2  AEM00041194  19950101        TMIN           120  NaN  NaN    S   NaN
# 3  AEM00041194  19950101        TAVG           198    H  NaN    S   NaN
# 4  AEM00041218  19950101        TMAX           238  NaN  NaN    S   NaN
#
#   country
# 0      AE
# 1      AE
# 2      AE
# 3      AE
# 4      AE

# %%
raw_data_us = raw_data[raw_data.country == 'US']

# %%
raw_data_us.head()
# Out:
#            station      date metric_name  metric_value var1 var2 var3   var4  \
# 43961  USC00010008  19950101        PRCP            13  NaN  NaN    0  700.0
# 43962  USC00010008  19950101        SNOW             0    P  NaN    0    NaN
# 43963  USC00010008  19950101        SNWD             0  NaN  NaN    0    NaN
# 43964  USC00010063  19950101        PRCP            15  NaN  NaN    0  700.0
# 43965  USC00010063  19950101        SNOW             0    P  NaN    0    NaN
#
#       country
# 43961      US
# 43962      US
# 43963      US
# 43964      US
# 43965      US

# %%
for_states = pd.read_csv(r'C:\Users\Shilp\Documents\Shilpa\Shilpa MSBA\Semester 1\Programming for Analytics [CIS 9650]\Final Group Project\ghcnd-stations.txt', delim_whitespace=True, header = None, error_bad_lines=False )
# Out:
# b'Skipping line 3: expected 8 fields, saw 9\nSkipping line 11: expected 8 fields, saw 9\nSkipping line 91: expected 8 fields, saw 10\nSkipping line 221: expected 8 fields, saw 9\nSkipping line 222: expected 8 fields, saw 10\nSkipping line 223: expected 8 fields, saw 9\nSkipping line 245: expected 8 fields, saw 11\nSkipping line 262: expected 8 fields, saw 9\nSkipping line 267: expected 8 fields, saw 9\nSkipping line 274: expected 8 fields, saw 9\nSkipping line 275: expected 8 fields, saw 10\nSkipping line 280: expected 8 fields, saw 9\nSkipping line 285: expected 8 fields, saw 9\nSkipping line 287: expected 8 fields, saw 9\nSkipping line 290: expected 8 fields, saw 9\nSkipping line 296: expected 8 fields, saw 9\nSkipping line 297: expected 8 fields, saw 10\nSkipping line 309: expected 8 fields, saw 10\nSkipping line 332: expected 8 fields, saw 9\nSkipping line 334: expected 8 fields, saw 9\nSkipping line 350: expected 8 fields, saw 10\nSkipping line 351: expected 8 fields, saw 9\nSkipping line 353: expected 8 fields, saw 9\nSkipping line 397: expected 8 fields, saw 9\nSkipping line 436: expected 8 fields, saw 9\nSkipping line 582: expected 8 fields, saw 9\nSkipping line 648: expected 8 fields, saw 9\nSkipping line 805: expected 8 fields, saw 9\nSkipping line 1225: expected 8 fields, saw 9\nSkipping line 1233: expected 8 fields, saw 9\nSkipping line 1764: expected 8 fields, saw 9\nSkipping line 1932: expected 8 fields, saw 9\nSkipping line 3103: expected 8 fields, saw 9\nSkipping line 3144: expected 8 fields, saw 9\nSkipping line 3162: expected 8 fields, saw 9\nSkipping line 3178: expected 8 fields, saw 9\nSkipping line 3190: expected 8 fields, saw 9\nSkipping line 3195: expected 8 fields, saw 10\nSkipping line 3198: expected 8 fields, saw 9\nSkipping line 3264: expected 8 fields, saw 9\nSkipping line 3332: expected 8 fields, saw 9\nSkipping line 3371: expected 8 fields, saw 9\nSkipping line 3619: expected 8 fields, saw 9\nSkipping line 3720: expected 8 fields, saw 9\nSkipping line 3845: expected 8 fields, saw 9\nSkipping line 3854: expected 8 fields, saw 9\nSkipping line 3875: expected 8 fields, saw 9\nSkipping line 3891: expected 8 fields, saw 10\nSkipping line 3968: expected 8 fields, saw 9\nSkipping line 3999: expected 8 fields, saw 9\nSkipping line 4040: expected 8 fields, saw 9\nSkipping line 4058: expected 8 fields, saw 9\nSkipping line 4100: expected 8 fields, saw 9\nSkipping line 4219: expected 8 fields, saw 10\nSkipping line 4459: expected 8 fields, saw 9\nSkipping line 4544: expected 8 fields, saw 9\nSkipping line 4658: expected 8 fields, saw 9\nSkipping line 4711: expected 8 fields, saw 9\nSkipping line 4800: expected 8 fields, saw 9\nSkipping line 4807: expected 8 fields, saw 9\nSkipping line 4883: expected 8 fields, saw 9\nSkipping line 4934: expected 8 fields, saw 9\nSkipping line 4936: expected 8 fields, saw 9\nSkipping line 4988: expected 8 fields, saw 9\nSkipping line 4990: expected 8 fields, saw 9\nSkipping line 4991: expected 8 fields, saw 10\nSkipping line 4994: expected 8 fields, saw 10\nSkipping line 5022: expected 8 fields, saw 9\nSkipping line 5096: expected 8 fields, saw 9\nSkipping line 5146: expected 8 fields, saw 9\nSkipping line 5284: expected 8 fields, saw 10\nSkipping line 5299: expected 8 fields, saw 9\nSkipping line 5347: expected 8 fields, saw 9\nSkipping line 5357: expected 8 fields, saw 9\nSkipping line 5370: expected 8 fields, saw 9\nSkipping line 5583: expected 8 fields, saw 9\nSkipping line 5584: expected 8 fields, saw 9\nSkipping line 5601: expected 8 fields, saw 9\nSkipping line 5679: expected 8 fields, saw 9\nSkipping line 5796: expected 8 fields, saw 9\nSkipping line 5838: expected 8 fields, saw 9\nSkipping line 6020: expected 8 fields, saw 9\nSkipping line 6044: expected 8 fields, saw 9\nSkipping line 6091: expected 8 fields, saw 9\nSkipping line 6150: expected 8 fields, saw 9\nSkipping line 6168: expected 8 fields, saw 9\nSkipping line 6194: expected 8 fields, saw 9\nSkipping line 6 ...
# b'Skipping line 72680: expected 8 fields, saw 9\nSkipping line 72681: expected 8 fields, saw 9\nSkipping line 72682: expected 8 fields, saw 9\nSkipping line 72683: expected 8 fields, saw 9\nSkipping line 72684: expected 8 fields, saw 9\nSkipping line 72685: expected 8 fields, saw 9\nSkipping line 72686: expected 8 fields, saw 9\nSkipping line 72687: expected 8 fields, saw 9\nSkipping line 72688: expected 8 fields, saw 9\nSkipping line 72689: expected 8 fields, saw 9\nSkipping line 72690: expected 8 fields, saw 9\nSkipping line 72737: expected 8 fields, saw 9\nSkipping line 72739: expected 8 fields, saw 9\nSkipping line 72775: expected 8 fields, saw 9\nSkipping line 72776: expected 8 fields, saw 9\nSkipping line 72780: expected 8 fields, saw 9\nSkipping line 72789: expected 8 fields, saw 9\nSkipping line 72793: expected 8 fields, saw 9\nSkipping line 72797: expected 8 fields, saw 9\nSkipping line 72799: expected 8 fields, saw 9\nSkipping line 72802: expected 8 fields, saw 9\nSkipping line 72814: expected 8 fields, saw 9\nSkipping line 72816: expected 8 fields, saw 9\nSkipping line 72823: expected 8 fields, saw 9\nSkipping line 72825: expected 8 fields, saw 9\nSkipping line 72826: expected 8 fields, saw 9\nSkipping line 72827: expected 8 fields, saw 9\nSkipping line 72832: expected 8 fields, saw 9\nSkipping line 72839: expected 8 fields, saw 9\nSkipping line 72843: expected 8 fields, saw 9\nSkipping line 72848: expected 8 fields, saw 9\nSkipping line 72852: expected 8 fields, saw 9\nSkipping line 72853: expected 8 fields, saw 9\nSkipping line 72857: expected 8 fields, saw 9\nSkipping line 72859: expected 8 fields, saw 9\nSkipping line 72878: expected 8 fields, saw 9\nSkipping line 72888: expected 8 fields, saw 9\nSkipping line 72889: expected 8 fields, saw 9\nSkipping line 72892: expected 8 fields, saw 9\nSkipping line 72895: expected 8 fields, saw 9\nSkipping line 72900: expected 8 fields, saw 9\nSkipping line 72904: expected 8 fields, saw 9\nSkipping line 72911: expected 8 fields, saw 9\nSkipping line 72917: expected 8 fields, saw 9\nSkipping line 72918: expected 8 fields, saw 9\nSkipping line 72951: expected 8 fields, saw 9\nSkipping line 72952: expected 8 fields, saw 9\nSkipping line 72969: expected 8 fields, saw 9\nSkipping line 72977: expected 8 fields, saw 9\nSkipping line 72979: expected 8 fields, saw 9\nSkipping line 72982: expected 8 fields, saw 9\nSkipping line 72989: expected 8 fields, saw 9\nSkipping line 72999: expected 8 fields, saw 9\nSkipping line 73006: expected 8 fields, saw 9\nSkipping line 73012: expected 8 fields, saw 9\nSkipping line 73013: expected 8 fields, saw 9\nSkipping line 73016: expected 8 fields, saw 9\nSkipping line 73023: expected 8 fields, saw 9\nSkipping line 73035: expected 8 fields, saw 9\nSkipping line 73039: expected 8 fields, saw 9\nSkipping line 73040: expected 8 fields, saw 9\nSkipping line 73043: expected 8 fields, saw 9\nSkipping line 73048: expected 8 fields, saw 9\nSkipping line 73050: expected 8 fields, saw 9\nSkipping line 73055: expected 8 fields, saw 9\nSkipping line 73059: expected 8 fields, saw 9\nSkipping line 73063: expected 8 fields, saw 9\nSkipping line 73064: expected 8 fields, saw 9\nSkipping line 73065: expected 8 fields, saw 9\nSkipping line 73073: expected 8 fields, saw 9\nSkipping line 73074: expected 8 fields, saw 9\nSkipping line 73083: expected 8 fields, saw 9\nSkipping line 73089: expected 8 fields, saw 9\nSkipping line 73100: expected 8 fields, saw 9\nSkipping line 73137: expected 8 fields, saw 9\nSkipping line 73139: expected 8 fields, saw 9\nSkipping line 73148: expected 8 fields, saw 9\nSkipping line 73155: expected 8 fields, saw 9\nSkipping line 73173: expected 8 fields, saw 9\nSkipping line 73198: expected 8 fields, saw 9\nSkipping line 73200: expected 8 fields, saw 9\nSkipping line 73202: expected 8 fields, saw 9\nSkipping line 73203: expected 8 fields, saw 9\nSkipping line 73205: expected 8 fields, saw 9\nSkipping line 73206: expected 8 fields, saw 9\nSki ...

# %%
for_states.head()
# Out:
#              0        1        2      3      4      5         6      7
# 0  ACW00011604  17.1167 -61.7833   10.1     ST  JOHNS  COOLIDGE    FLD
# 1  ACW00011647  17.1333 -61.7833   19.2     ST  JOHNS       NaN    NaN
# 2  AEM00041194  25.2550  55.3640   10.4  DUBAI   INTL     41194    NaN
# 3  AEM00041217  24.4330  54.6510   26.8    ABU  DHABI      INTL  41217
# 4  AEM00041218  24.2620  55.6090  264.9     AL    AIN      INTL  41218

# %%
for_states.columns = ['station', 'latitude','longitude','elevation','State','Street1','Street2','Street3']

# %%
us_station_state = pd.merge(raw_data_us,for_states[['station','State']],on='station',how='left')

# %%
us_station_state.head()
# Out:
#        station      date metric_name  metric_value var1 var2 var3   var4  \
# 0  USC00010008  19950101        PRCP            13  NaN  NaN    0  700.0
# 1  USC00010008  19950101        SNOW             0    P  NaN    0    NaN
# 2  USC00010008  19950101        SNWD             0  NaN  NaN    0    NaN
# 3  USC00010063  19950101        PRCP            15  NaN  NaN    0  700.0
# 4  USC00010063  19950101        SNOW             0    P  NaN    0    NaN
#
#   country State
# 0      US    AL
# 1      US    AL
# 2      US    AL
# 3      US    AL
# 4      US    AL

# %%
us_station_state.drop(['var1','var2','var3','var4','country'], 1)
# Out:
#               station      date metric_name  metric_value State
# 0         USC00010008  19950101        PRCP            13    AL
# 1         USC00010008  19950101        SNOW             0    AL
# 2         USC00010008  19950101        SNWD             0    AL
# 3         USC00010063  19950101        PRCP            15    AL
# 4         USC00010063  19950101        SNOW             0    AL
# ...               ...       ...         ...           ...   ...
# 17168483  USC00288880  19951231        TMAX            67    NJ
# 17168484  USC00288880  19951231        TMIN           -39    NJ
# 17168485  USC00288880  19951231        TOBS            33    NJ
# 17168486  USC00288880  19951231        PRCP            10    NJ
# 17168487  USC00288880  19951231        SNOW             0    NJ
#
# [17168488 rows x 5 columns]

# %%
state_metrics = us_station_state.groupby(['State','date','metric_name']).mean().reset_index()

# %%
state_metrics.head()
# Out:
#   State      date metric_name  metric_value  var4
# 0    AK  19950101        ACMH     80.000000   NaN
# 1    AK  19950101        ACSH     85.000000   NaN
# 2    AK  19950101        AWND     47.666667   NaN
# 3    AK  19950101        FMTM   1537.666667   NaN
# 4    AK  19950101        PGTM   1596.000000   NaN

# %%
state_metrics_filtered = state_metrics.loc[state_metrics['metric_name'].isin(['TMIN','TMAX','TAVG','SNOW','PRCP'])]

# %%
state_metrics_filtered.head()
# Out:
#    State      date metric_name  metric_value         var4
# 5     AK  19950101        PRCP     23.149123  1476.306818
# 6     AK  19950101        SNOW      0.344828          NaN
# 8     AK  19950101        TAVG    -18.000000          NaN
# 9     AK  19950101        TMAX    -24.312500  1466.058824
# 10    AK  19950101        TMIN    -87.422680  1466.453488

# %%
state_metrics_filtered.drop(['var4'], 1)
# Out:
#        State      date metric_name  metric_value
# 5         AK  19950101        PRCP     23.149123
# 6         AK  19950101        SNOW      0.344828
# 8         AK  19950101        TAVG    -18.000000
# 9         AK  19950101        TMAX    -24.312500
# 10        AK  19950101        TMIN    -87.422680
# ...      ...       ...         ...           ...
# 366132    WY  19951231        PRCP     40.615819
# 366136    WY  19951231        SNOW     30.971698
# 366141    WY  19951231        TAVG    -65.087500
# 366142    WY  19951231        TMAX     -1.170455
# 366143    WY  19951231        TMIN    -85.800000
#
# [79921 rows x 4 columns]

# %%
state_metrics_filtered.to_csv(r'C:\Users\Shilp\Documents\Shilpa\Shilpa MSBA\Semester 1\Programming for Analytics [CIS 9650]\Final Group Project\1995.csv')
